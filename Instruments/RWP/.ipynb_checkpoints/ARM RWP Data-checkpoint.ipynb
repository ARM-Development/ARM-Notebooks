# %%
import act
import xarray as xr
import numpy as np
import pandas as pd
import glob
import scipy
import sys

# %%
hi_file = glob.glob('./sgp915rwpprecipmomhiC1.a0/*')
lo_file = glob.glob('./sgp915rwpprecipmomloC1.a0/*')

# %%
hi_obj = act.io.armfiles.read_netcdf(hi_file)
lo_obj = act.io.armfiles.read_netcdf(lo_file)
print(lo_obj)
# Out:
# <xarray.Dataset>
# Dimensions:                            (time: 468, height: 123)
# Coordinates:
#   * time                               (time) datetime64[ns] 2021-06-27T00:01...
#   * height                             (height) float32 149.4 ... 8.027e+03
# Data variables: (12/18)
#     base_time                          datetime64[ns] 2021-06-27
#     time_offset                        (time) datetime64[ns] 2021-06-27T00:01...
#     interpulse_period                  float32 ...
#     pulse_width                        float32 ...
#     first_bin_velocity                 float32 ...
#     num_frequency_domain_integrations  float64 ...
#     ...                                 ...
#     spectral_width                     (time, height) float32 dask.array<chunksize=(468, 123), meta=np.ndarray>
#     signal_to_noise_ratio              (time, height) float32 dask.array<chunksize=(468, 123), meta=np.ndarray>
#     mean_noise                         (time, height) float32 dask.array<chunksize=(468, 123), meta=np.ndarray>
#     lat                                float32 ...
#     lon                                float32 ...
#     alt                                float32 ...
# Attributes: (12/18)
#     command_line:          rwp_ingest -n 915rwp -s sgp -f C1
#     Conventions:           ARM-1.2
#     process_version:       ingest-rwp-11.2-0.el7
#     dod_version:           915rwpprecipmomlo-a0-1.1
#     input_source:          /data/collection/sgp/sgp915rwpC1.00/2021-06-27_00-...
#     site_id:               sgp
#     ...                    ...
#     doi:                   10.5439/1573770
#     history:               created by user dsmgr on machine flint at 2021-06-...
#     _file_dates:           ['20210627']
#     _file_times:           ['000138']
#     _datastream:           sgp915rwpprecipmomloC1.a0
#     _arm_standards_flag:   1

# %%
display = act.plotting.TimeSeriesDisplay({'lo': lo_obj, 'hi': hi_obj}, figsize=(15,10), subplot_shape=(3,2))
display.plot('signal_to_noise_ratio', dsname='lo', subplot_index=(0,0))
display.plot('radial_velocity', dsname='lo', subplot_index=(1,0))
display.plot('spectral_width', dsname='lo', subplot_index=(2,0))

display.plot('signal_to_noise_ratio', dsname='hi', subplot_index=(0,1))
display.plot('radial_velocity', dsname='hi', subplot_index=(1,1))
display.plot('spectral_width', dsname='hi', subplot_index=(2,1))
# Out:
# <AxesSubplot:title={'center':'hi spectral_width on 20210627'}, xlabel='Time [UTC]', ylabel='(m)'>

# %%
# SNR Filter for lo mode
# Take last 2 points
snr_lo = lo_obj['signal_to_noise_ratio'].values[:,-2:]

# Throw out larger return that could be echo
idx = np.where(snr_lo > -12.5)
snr_lo[idx] = np.nan
lo_mean = np.nanmean(snr_lo)
lo_std = np.nanstd(snr_lo)
lo_threshold = lo_mean + 10. * lo_std

# SNR Filter for lo mode
# Take last 2 points
snr_hi = hi_obj['signal_to_noise_ratio'].values[:,-2:]

# Throw out larger return that could be echo
idx = np.where(snr_hi > -12.5)
snr_hi[idx] = np.nan
hi_mean = np.nanmean(snr_hi)
hi_std = np.nanstd(snr_hi)
hi_threshold = hi_mean + 10. * hi_std

lo_obj = lo_obj.where(lo_obj.signal_to_noise_ratio > lo_threshold)
hi_obj = hi_obj.where(hi_obj.signal_to_noise_ratio > hi_threshold)
print(lo_threshold, hi_threshold)
# Out:
# 0.9599065780639648 3.4099373817443848

# %%
# Boxcar filter
snr_lo = lo_obj['signal_to_noise_ratio'].values
n_time = np.shape(snr_lo)[0]
n_bins = np.shape(snr_lo)[1]

ct = np.zeros([n_time, n_bins])
for i in range(2, n_time-3):
    for j in range(2, n_bins-3):
        if np.sum(snr_lo[i-2:i+2, j-2:j+2] > lo_threshold) >= 10:
            ct[i, j] = 1
mask = np.where(ct != 1)
print(mask)
lo_obj.signal_to_noise_ratio.values[mask] = np.nan

snr_hi = hi_obj['signal_to_noise_ratio'].values
n_time = np.shape(snr_hi)[0]
n_bins = np.shape(snr_hi)[1]

ct = np.zeros([n_time, n_bins])
for i in range(2, n_time-3):
    for j in range(2, n_bins-3):
        if np.sum(snr_hi[i-2:i+2, j-2:j+2] > hi_threshold) >= 10:
            ct[i, j] = 1
mask = np.where(ct != 1)
print(mask)
hi_obj.signal_to_noise_ratio.values[mask] = np.nan
# Out:
# (array([  0,   0,   0, ..., 467, 467, 467]), array([  0,   1,   2, ..., 120, 121, 122]))
# (array([  0,   0,   0, ..., 532, 532, 532]), array([  0,   1,   2, ..., 217, 218, 219]))

# %%
display = act.plotting.TimeSeriesDisplay({'lo': lo_obj, 'hi': hi_obj}, figsize=(15,10), subplot_shape=(3,2))
display.plot('signal_to_noise_ratio', dsname='lo', subplot_index=(0,0))
display.plot('radial_velocity', dsname='lo', subplot_index=(1,0))
display.plot('spectral_width', dsname='lo', subplot_index=(2,0))

display.plot('signal_to_noise_ratio', dsname='hi', subplot_index=(0,1))
display.plot('radial_velocity', dsname='hi', subplot_index=(1,1))
display.plot('spectral_width', dsname='hi', subplot_index=(2,1))
# Out:
# <AxesSubplot:title={'center':'hi spectral_width on 20210627'}, xlabel='Time [UTC]', ylabel='(m)'>
